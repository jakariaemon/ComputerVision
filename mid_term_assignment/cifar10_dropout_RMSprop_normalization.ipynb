# %% [markdown]
# <a href="https://colab.research.google.com/github/jakariaemon/ComputerVision/blob/main/mid_term_assignment/cifar10_dropout_RMSprop_normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import pickle
import warnings

warnings.filterwarnings('ignore')
sns.set_style('dark')

# %%
from keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 1)
# (10000, 1)

# %%
data_dict = {0 : "Airplane",
             1 : "Car",
             2 : "Bird",
             3 : "Cat",
             4 : "Deer",
             5 : "Dog",
             6 : "Frog",
             7 : "Horse",
             8 : "Ship",
             9 : "Truck",
            }

# %%
def get_ten_random_images():
   
    d = {}
    while len(d.keys()) < 10:
        idx = random.randint(0, len(y_train)-1)
        if y_train[idx][0] not in d.keys():
            d[y_train[idx][0]] = idx
    return d

# %%
d = get_ten_random_images()
rows= 2
cols=5
fig,axes = plt.subplots(rows, cols, figsize = (15,6))
axes = axes.ravel()
for i in range(1, rows*cols+1):
    axes[i-1].imshow(X_train[d[i-1]])
    axes[i-1].axis('off')
    axes[i-1].set_title(data_dict[i-1], fontsize=15)
fig.suptitle('10 Random Images from Dataset of each class', fontsize = 20)
plt.show()

# %%
import keras

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
mean = np.mean(X_train, axis = (0,1,2,3))
std = np.std(X_train, axis = (0,1,2,3))

# %%
X_train = (X_train-mean)/(std + 1e-7)
X_test = (X_test-mean)/(std + 1e-7)

# %%
from keras.utils import np_utils
y_train_cat = keras.utils.np_utils.to_categorical(y_train,10)
y_test_cat = keras.utils.np_utils.to_categorical(y_test,10)

# %%
input_shape = X_train.shape[1:]

# %%
input_shape
# Out:
# (32, 32, 3)

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, AveragePooling2D, Flatten, Dropout, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from keras.callbacks import TensorBoard
from keras import regularizers
from tensorflow.keras import optimizers
from keras.optimizers import rmsprop_v2
import tensorflow as tf

# %%
weight_decay = 1e-4

# %%
model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (3,3), padding='same', input_shape = input_shape, kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(filters = 32, kernel_size = (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.2))

model.add(Conv2D(filters = 64, kernel_size = (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(filters = 64, kernel_size = (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))

model.add(Conv2D(filters = 128, kernel_size = (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(filters = 128, kernel_size = (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.4))



model.add(Flatten())

model.add(Dense(units = 10, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_2 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  activation_3 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  activation_4 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  activation_5 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 10)                20490
#
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________

# %%
model.compile(loss = 'categorical_crossentropy', optimizer= tf.keras.optimizers.RMSprop(lr = 0.001, decay = 1e-6), metrics=['accuracy'])

# %%
epochs_hist = model.fit(X_train, y_train_cat, batch_size=64, epochs=50, validation_split=0.2, shuffle=True)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 19s 12ms/step - loss: 1.8173 - accuracy: 0.4567 - val_loss: 1.3588 - val_accuracy: 0.5889
# Epoch 2/50
# 625/625 [==============================] - 7s 11ms/step - loss: 1.1312 - accuracy: 0.6399 - val_loss: 0.9302 - val_accuracy: 0.6989
# Epoch 3/50
# 625/625 [==============================] - 7s 11ms/step - loss: 0.9334 - accuracy: 0.7050 - val_loss: 0.8425 - val_accuracy: 0.7330
# Epoch 4/50
# 625/625 [==============================] - 7s 12ms/step - loss: 0.8340 - accuracy: 0.7408 - val_loss: 0.7987 - val_accuracy: 0.7467
# Epoch 5/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.7628 - accuracy: 0.7651 - val_loss: 0.7219 - val_accuracy: 0.7911
# Epoch 6/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.7069 - accuracy: 0.7886 - val_loss: 0.6703 - val_accuracy: 0.8060
# Epoch 7/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.6642 - accuracy: 0.8066 - val_loss: 0.7433 - val_accuracy: 0.7898
# Epoch 8/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.6329 - accuracy: 0.8166 - val_loss: 0.7045 - val_accuracy: 0.8023
# Epoch 9/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.6084 - accuracy: 0.8271 - val_loss: 0.6675 - val_accuracy: 0.8127
# Epoch 10/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.5783 - accuracy: 0.8418 - val_loss: 0.6543 - val_accuracy: 0.8215
# Epoch 11/50
# 625/625 [==============================] - 7s 11ms/step - loss: 0.5601 - accuracy: 0.8475 - val_loss: 0.6941 - val_accuracy: 0.8126
# Epoch 12/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.5456 - accuracy: 0.8533 - val_loss: 0.6664 - val_accuracy: 0.8247
# Epoch 13/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.5271 - accuracy: 0.8607 - val_loss: 0.7065 - val_accuracy: 0.8117
# Epoch 14/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.5138 - accuracy: 0.8702 - val_loss: 0.6486 - val_accuracy: 0.8348
# Epoch 15/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.5065 - accuracy: 0.8718 - val_loss: 0.6460 - val_accuracy: 0.8318
# Epoch 16/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.4920 - accuracy: 0.8788 - val_loss: 0.6357 - val_accuracy: 0.8434
# Epoch 17/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.4881 - accuracy: 0.8812 - val_loss: 0.6549 - val_accuracy: 0.8403
# Epoch 18/50
# 625/625 [==============================] - 6s 10ms/step - loss: 0.4797 - accuracy: 0.8848 - val_loss: 0.6308 - val_accuracy: 0.8444
# Epoch 19/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4697 - accuracy: 0.8893 - val_loss: 0.7060 - val_accuracy: 0.8294
# Epoch 20/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4670 - accuracy: 0.8910 - val_loss: 0.6725 - val_accuracy: 0.8376
# Epoch 21/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4619 - accuracy: 0.8956 - val_loss: 0.6656 - val_accuracy: 0.8403
# Epoch 22/50
# 625/625 [==============================] - 7s 11ms/step - loss: 0.4567 - accuracy: 0.8959 - val_loss: 0.6707 - val_accuracy: 0.8408
# Epoch 23/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4523 - accuracy: 0.8978 - val_loss: 0.6473 - val_accuracy: 0.8494
# Epoch 24/50
# 625/625 [==============================] - 7s 12ms/step - loss: 0.4502 - accuracy: 0.9006 - val_loss: 0.6848 - val_accuracy: 0.8426
# Epoch 25/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4488 - accuracy: 0.9021 - val_loss: 0.6692 - val_accuracy: 0.8426
# Epoch 26/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4385 - accuracy: 0.9063 - val_loss: 0.7163 - val_accuracy: 0.8421
# Epoch 27/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4392 - accuracy: 0.9069 - val_loss: 0.6729 - val_accuracy: 0.8486
# Epoch 28/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4413 - accuracy: 0.9068 - val_loss: 0.6866 - val_accuracy: 0.8417
# Epoch 29/50
# 625/625 [==============================] - 7s 11ms/step - loss: 0.4345 - accuracy: 0.9093 - val_loss: 0.6904 - val_accuracy: 0.8431
# Epoch 30/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4284 - accuracy: 0.9118 - val_loss: 0.6969 - val_accuracy: 0.8444
# Epoch 31/50
# 625/625 [==============================] - 7s 11ms/step - loss: 0.4249 - accuracy: 0.9144 - val_loss: 0.6740 - val_accuracy: 0.8501
# Epoch 32/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4235 - accuracy: 0.9141 - val_loss: 0.7121 - val_accuracy: 0.8459
# Epoch 33/50
# 625/625 [==============================] - 7s 12ms/step - loss: 0.4273 - accuracy: 0.9133 - val_loss: 0.6978 - val_accuracy: 0.8471
# Epoch 34/50
# 625/625 [==============================] - 7s 12ms/step - loss: 0.4199 - accuracy: 0.9168 - val_loss: 0.7266 - val_accuracy: 0.8395
# Epoch 35/50
# 625/625 [==============================] - 7s 11ms/step - loss: 0.4198 - accuracy: 0.9179 - val_loss: 0.6839 - val_accuracy: 0.8537
# Epoch 36/50
# 625/625 [==============================] - 7s 11ms/step - loss: 0.4147 - accuracy: 0.9198 - val_loss: 0.6957 - val_accuracy: 0.8524
# Epoch 37/50
# 625/625 [==============================] - 7s 11ms/step - loss: 0.4175 - accuracy: 0.9181 - val_loss: 0.6997 - val_accuracy: 0.8449
# Epoch 38/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4133 - accuracy: 0.9200 - val_loss: 0.7213 - val_accuracy: 0.8439
# Epoch 39/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4142 - accuracy: 0.9204 - val_loss: 0.7091 - val_accuracy: 0.8458
# Epoch 40/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4123 - accuracy: 0.9217 - val_loss: 0.6947 - val_accuracy: 0.8498
# Epoch 41/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4135 - accuracy: 0.9222 - val_loss: 0.7275 - val_accuracy: 0.8437
# Epoch 42/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4113 - accuracy: 0.9212 - val_loss: 0.7037 - val_accuracy: 0.8539
# Epoch 43/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4078 - accuracy: 0.9226 - val_loss: 0.7089 - val_accuracy: 0.8498
# Epoch 44/50
# 625/625 [==============================] - 7s 12ms/step - loss: 0.4039 - accuracy: 0.9258 - val_loss: 0.7044 - val_accuracy: 0.8517
# Epoch 45/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4090 - accuracy: 0.9245 - val_loss: 0.6860 - val_accuracy: 0.8546
# Epoch 46/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4053 - accuracy: 0.9244 - val_loss: 0.7105 - val_accuracy: 0.8462
# Epoch 47/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4044 - accuracy: 0.9247 - val_loss: 0.7391 - val_accuracy: 0.8484
# Epoch 48/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.4027 - accuracy: 0.9255 - val_loss: 0.7079 - val_accuracy: 0.8494
# Epoch 49/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.3966 - accuracy: 0.9287 - val_loss: 0.7216 - val_accuracy: 0.8502
# Epoch 50/50
# 625/625 [==============================] - 7s 10ms/step - loss: 0.3947 - accuracy: 0.9278 - val_loss: 0.7431 - val_accuracy: 0.8467

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(epochs_hist.history['val_accuracy'], label = 'CV Acc')
plt.plot(epochs_hist.history['accuracy'], label = 'Training Acc')
plt.title("Model Accuracy")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid()
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs_hist.history['val_loss'], label = 'CV Loss')
plt.plot(epochs_hist.history['loss'], label = 'Training Loss')
plt.title("Model Loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()
